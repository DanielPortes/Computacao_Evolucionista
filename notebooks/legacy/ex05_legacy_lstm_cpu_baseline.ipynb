# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from pandas import Series

from sklearn.preprocessing import MinMaxScaler
from tensorflow import keras
from keras.models import Sequential, Model
from keras.layers import Dense, LSTM, CuDNNLSTM
from sklearn.metrics import mean_squared_error, mean_absolute_error

import datetime
import time
import tensorflow as tf
tf.config.run_functions_eagerly(True)

# %%
time = np.arange(0,768,0.1);
amplitute = np.sin(time)
plt.plot(time,amplitute)

# %%
#using the MachineLearningMastery formula for splitting up the dataset to predictors and target
#reference: https://towardsdatascience.com/single-and-multi-step-temperature-time-series-forecasting-for-vilnius-using-lstm-deep-learning-b9719a0009de
def create_X_Y(ts: np.array, lag=1, n_ahead=1, target_index=0) -> tuple:
    """
    A method to create X and Y matrix from a time series array for the training of 
    deep learning models 
    """
    # Extracting the number of features that are passed from the array 
    n_features = ts.shape[1]
    
    # Creating placeholder lists
    X, Y = [], []

    if len(ts) - lag <= 0:
        X.append(ts)
    else:
        for i in range(len(ts) - lag - n_ahead):
            Y.append(ts[(i + lag):(i + lag + n_ahead), target_index])
            X.append(ts[i:(i + lag)])

    X, Y = np.array(X), np.array(Y)

    # Reshaping the X array to an LSTM input shape 
    X = np.reshape(X, (X.shape[0], lag, n_features))

    return X, Y

# %%
lag = 256
n_ahead = 128
train_share = 0.7
val_share = 0.8
epochs = 10
batch_size = 1

# %%
data = amplitute.reshape(-1,1)
scaler = MinMaxScaler()
scaler.fit(data)
ts_scaled = scaler.transform(data)

# %%
X, Y = create_X_Y(ts_scaled, lag=lag, n_ahead=n_ahead)

# %%
Xtrain, Ytrain = X[0:int(X.shape[0]* train_share)], Y[0:int(X.shape[0]*train_share)]
Xtest, Ytest = X[int(X.shape[0] * val_share):], Y[int(X.shape[0]*val_share):]
Xval, Yval = X[int(X.shape[0] * train_share):int(X.shape[0]*val_share)], Y[int(X.shape[0]*train_share):int(X.shape[0]*val_share)]

# %%
model = Sequential()

#model.add(LSTM(16, activation='tanh', input_shape=(Xtrain.shape[1], Xtrain.shape[2]), return_sequences=True))
model.add(CuDNNLSTM(16,input_shape=(Xtrain.shape[1], Xtrain.shape[2]), return_sequences=True))
#model.add(LSTM(8, activation='tanh', return_sequences=False))
model.add(CuDNNLSTM(8,return_sequences=False))
model.add(Dense(128))

early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=2, min_delta=0.001)
model.summary()

model.compile(optimizer = keras.optimizers.Adam(learning_rate=0.001), loss='mae', metrics='mae')
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  cu_dnnlstm_4 (CuDNNLSTM)    (None, 256, 16)           1216
#
#  cu_dnnlstm_5 (CuDNNLSTM)    (None, 8)                 832
#
#  dense_2 (Dense)             (None, 128)               1152
#
# =================================================================
# Total params: 3,200
# Trainable params: 3,200
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(Xtrain, Ytrain, epochs=epochs, validation_data=(Xval, Yval), shuffle=False, callbacks=[early_stopping])
# Out:
# Epoch 1/10
#   1/160 [..............................] - ETA: 17s - loss: 0.5029 - mae: 0.5029
# /home/portes/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/data/ops/structured_function.py:254: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   warnings.warn(
# 160/160 [==============================] - 14s 88ms/step - loss: 0.3612 - mae: 0.3612 - val_loss: 0.3139 - val_mae: 0.3139
# Epoch 2/10
# 160/160 [==============================] - 13s 81ms/step - loss: 0.2657 - mae: 0.2657 - val_loss: 0.1797 - val_mae: 0.1797
# Epoch 3/10
#  12/160 [=>............................] - ETA: 11s - loss: 0.1726 - mae: 0.1726
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 history = model.fit(Xtrain, Ytrain, epochs=epochs, validation_data=(Xval, Yval), shuffle=False, callbacks=[early_stopping])
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/keras/engine/training.py:1685, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1677 with tf.profiler.experimental.Trace(
#    1678     "train",
#    1679     epoch_num=epoch,
#    (...)
#    1682     _r=1,
#    1683 ):
#    1684     callbacks.on_train_batch_begin(step)
# -> 1685     tmp_logs = self.train_function(iterator)
#    1686     if data_handler.should_sync:
#    1687         context.async_wait()
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/keras/engine/training.py:1284, in Model.make_train_function.<locals>.train_function(iterator)
#    1282 def train_function(iterator):
#    1283     """Runs a training execution with a single step."""
# -> 1284     return step_function(self, iterator)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/keras/engine/training.py:1268, in Model.make_train_function.<locals>.step_function(model, iterator)
#    1264     run_step = tf.function(
#    1265         run_step, jit_compile=True, reduce_retracing=True
#    1266     )
#    1267 data = next(iterator)
# -> 1268 outputs = model.distribute_strategy.run(run_step, args=(data,))
#    1269 outputs = reduce_per_replica(
#    1270     outputs,
#    1271     self.distribute_strategy,
#    1272     reduction=self.distribute_reduction_method,
#    1273 )
#    1274 return outputs
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/distribute/distribute_lib.py:1316, in StrategyBase.run(***failed resolving arguments***)
#    1311 with self.scope():
#    1312   # tf.distribute supports Eager functions, so AutoGraph should not be
#    1313   # applied when the caller is also in Eager mode.
#    1314   fn = autograph.tf_convert(
#    1315       fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 1316   return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/distribute/distribute_lib.py:2895, in StrategyExtendedV1.call_for_each_replica(self, fn, args, kwargs)
#    2893   kwargs = {}
#    2894 with self._container_strategy().scope():
# -> 2895   return self._call_for_each_replica(fn, args, kwargs)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/distribute/distribute_lib.py:3696, in _DefaultDistributionExtended._call_for_each_replica(self, fn, args, kwargs)
#    3694 def _call_for_each_replica(self, fn, args, kwargs):
#    3695   with ReplicaContext(self._container_strategy(), replica_id_in_sync_group=0):
# -> 3696     return fn(*args, **kwargs)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/autograph/impl/api.py:595, in call_with_unspecified_conversion_status.<locals>.wrapper(*args, **kwargs)
#     593 def wrapper(*args, **kwargs):
#     594   with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.UNSPECIFIED):
# --> 595     return func(*args, **kwargs)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/keras/engine/training.py:1249, in Model.make_train_function.<locals>.step_function.<locals>.run_step(data)
#    1248 def run_step(data):
# -> 1249     outputs = model.train_step(data)
#    1250     # Ensure counter is updated only if `train_step` succeeds.
#    1251     with tf.control_dependencies(_minimum_control_deps(outputs)):
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/keras/engine/training.py:1050, in Model.train_step(self, data)
#    1048 # Run forward pass.
#    1049 with tf.GradientTape() as tape:
# -> 1050     y_pred = self(x, training=True)
#    1051     loss = self.compute_loss(x, y, y_pred, sample_weight)
#    1052 self._validate_target_and_loss(y, loss)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/keras/engine/training.py:558, in Model.__call__(self, *args, **kwargs)
#     554         super().__call__(inputs, *copied_args, **copied_kwargs)
#     556     layout_map_lib._map_subclass_model_variable(self, self._layout_map)
# --> 558 return super().__call__(*args, **kwargs)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/keras/engine/base_layer.py:1145, in Layer.__call__(self, *args, **kwargs)
#    1140     inputs = self._maybe_cast_inputs(inputs, input_list)
#    1142 with autocast_variable.enable_auto_cast_variables(
#    1143     self._compute_dtype_object
#    1144 ):
# -> 1145     outputs = call_fn(inputs, *args, **kwargs)
#    1147 if self._activity_regularizer:
#    1148     self._handle_activity_regularization(inputs, outputs)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/keras/utils/traceback_utils.py:96, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      94 bound_signature = None
#      95 try:
# ---> 96     return fn(*args, **kwargs)
#      97 except Exception as e:
#      98     if hasattr(e, "_keras_call_info_injected"):
#      99         # Only inject info for the innermost failing call
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/keras/engine/sequential.py:412, in Sequential.call(self, inputs, training, mask)
#     410     if not self.built:
#     411         self._init_graph_network(self.inputs, self.outputs)
# --> 412     return super().call(inputs, training=training, mask=mask)
#     414 outputs = inputs  # handle the corner case where self.layers is empty
#     415 for layer in self.layers:
#     416     # During each iteration, `inputs` are the inputs to `layer`, and
#     417     # `outputs` are the outputs of `layer` applied to `inputs`. At the
#     418     # end of each iteration `inputs` is set to `outputs` to prepare for
#     419     # the next layer.
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/keras/engine/functional.py:512, in Functional.call(self, inputs, training, mask)
#     493 @doc_controls.do_not_doc_inheritable
#     494 def call(self, inputs, training=None, mask=None):
#     495     """Calls the model on new inputs.
#     496
#     497     In this case `call` just reapplies
#    (...)
#     510         a list of tensors if there are more than one outputs.
#     511     """
# --> 512     return self._run_internal_graph(inputs, training=training, mask=mask)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/keras/engine/functional.py:669, in Functional._run_internal_graph(self, inputs, training, mask)
#     666     continue  # Node is not computable, try skipping.
#     668 args, kwargs = node.map_arguments(tensor_dict)
# --> 669 outputs = node.layer(*args, **kwargs)
#     671 # Update tensor_dict.
#     672 for x_id, y in zip(
#     673     node.flat_output_ids, tf.nest.flatten(outputs)
#     674 ):
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/keras/layers/rnn/base_rnn.py:556, in RNN.__call__(self, inputs, initial_state, constants, **kwargs)
#     551 inputs, initial_state, constants = rnn_utils.standardize_args(
#     552     inputs, initial_state, constants, self._num_constants
#     553 )
#     555 if initial_state is None and constants is None:
# --> 556     return super().__call__(inputs, **kwargs)
#     558 # If any of `initial_state` or `constants` are specified and are Keras
#     559 # tensors, then add them to the inputs and temporarily modify the
#     560 # input_spec to include them.
#     562 additional_inputs = []
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/keras/engine/base_layer.py:1070, in Layer.__call__(self, *args, **kwargs)
#    1065 # Accept NumPy and scalar inputs by converting to Tensors.
#    1066 if any(
#    1067     isinstance(x, (tf.Tensor, np.ndarray, float, int))
#    1068     for x in input_list
#    1069 ):
# -> 1070     inputs = tf.nest.map_structure(
#    1071         _convert_numpy_or_python_types, inputs
#    1072     )
#    1073     input_list = tf.nest.flatten(inputs)
#    1075 # Handle `mask` propagation from previous layer to current layer. Masks
#    1076 # can be propagated explicitly via the `mask` argument, or implicitly
#    1077 # via setting the `_keras_mask` attribute on the inputs to a Layer.
#    1078 # Masks passed explicitly take priority.
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/util/nest.py:917, in map_structure(func, *structure, **kwargs)
#     913 flat_structure = (flatten(s, expand_composites) for s in structure)
#     914 entries = zip(*flat_structure)
#     916 return pack_sequence_as(
# --> 917     structure[0], [func(*x) for x in entries],
#     918     expand_composites=expand_composites)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/util/nest.py:917, in <listcomp>(.0)
#     913 flat_structure = (flatten(s, expand_composites) for s in structure)
#     914 entries = zip(*flat_structure)
#     916 return pack_sequence_as(
# --> 917     structure[0], [func(*x) for x in entries],
#     918     expand_composites=expand_composites)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/keras/engine/base_layer.py:3725, in _convert_numpy_or_python_types(x)
#    3723 def _convert_numpy_or_python_types(x):
#    3724     if isinstance(x, (tf.Tensor, np.ndarray, float, int)):
# -> 3725         return tf.convert_to_tensor(x)
#    3726     return x
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1162, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1157   arg_names = tf_inspect.getargspec(dispatch_target).args
#    1158   iterable_params = [
#    1159       (name, arg_names.index(name)) for name in iterable_parameters
#    1160   ]
# -> 1162 @traceback_utils.filter_traceback
#    1163 def op_dispatch_handler(*args, **kwargs):
#    1164   """Call `dispatch_target`, peforming dispatch when appropriate."""
#    1166   # Type-based dispatch system (dispatch v2):
#
# KeyboardInterrupt:

# %%
yhat = model.predict(Xtest)
yhat.shape

# %%
pred_n_ahead = pd.DataFrame(yhat[0])
actual_n_ahead = pd.DataFrame(Ytest[0])

pred_n_ahead = pd.DataFrame(scaler.inverse_transform(pred_n_ahead))
actual_n_ahead = pd.DataFrame(scaler.inverse_transform(actual_n_ahead))

# %%
plt.figure(figsize=(15,8))
plt.plot(pred_n_ahead, color='C0', marker='o', label='Predicted')
plt.plot(actual_n_ahead, color='C1', marker='o', label='Actual', alpha=0.6)
plt.title('Predicted vs Actual')
plt.gcf().axes[0].yaxis.get_major_formatter().set_scientific(False)
plt.legend()
plt.show

# %%
def forecast_accuracy(forecast,actual):
  mape = np.mean(np.abs(forecast - actual)/np.abs(actual))
  me = np.mean(forecast - actual)
  mae = np.mean(np.abs(forecast - actual))
  rmse = np.mean((forecast - actual)**2)**.5
  corr = np.corrcoef(forecast,actual)[0,1]
  return({'mape':mape, 'me':me, 'mae':mae, 'rmse':rmse, 'corr':corr})

forecast_accuracy(yhat,Ytest)

# %% [markdown]
# # Execucao Principal\n\nNotebook principal para rodar `CE2`, `CE3`, `CE4` e `CE5` com budgets reduzidos e gerar figuras de analise em `plotly`.

# %%
from ce.analysis.run_all import NotebookRunConfig, build_plotly_figures, run_all_exercises

config = NotebookRunConfig()
results = run_all_exercises(config)
figures = build_plotly_figures(results)

# %%
for name, frame in results.as_dict().items():
    print(f'## {name.upper()}')
    display(frame)
# Out:
# ## CE2
#   algorithm  function_id  dimension  budget       minimum       maximum  \
# 0        GA            3          2      12  13550.098594  13550.098594
# 1        ES            3          2      12   2730.161855   2730.161855
# 2        EP            3          2      12   2703.782154   2703.782154
# 3        DE            3          2      12   6437.978323   6437.978323
# 4       PSO            3          2      12  10131.396198  10131.396198
# 5       ABC            3          2      12  13550.098594  13550.098594
#
#            mean        median  std
# 0  13550.098594  13550.098594  0.0
# 1   2730.161855   2730.161855  0.0
# 2   2703.782154   2703.782154  0.0
# 3   6437.978323   6437.978323  0.0
# 4  10131.396198  10131.396198  0.0
# 5  13550.098594  13550.098594  0.0
# ## CE3
#   algorithm  instance problem_type  best_cost  relative_error_percent  \
# 0        GA  berlin52          TSP    26289.0              248.568019
# ...

# %%
for name, figure in figures.items():
    print(f'## Figura {name.upper()}')
    figure.show()

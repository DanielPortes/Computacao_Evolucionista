# %%
# # !pip install sklearn-deap
# # !pip install pycaret
# # !pip install --force scikit-learn==1.0.2
# # !pip install sklearn
# # !pip install numpy
# # # !pip uninstall -y sklearn
# # # !pip uninstall -y scikit-learn
# # !pip install --force numpy==1.19.5
# # # !pip uninstall -y scikit-learn
# # !pip install --force scikit-learn==0.23.2
#
# !pip uninstall --force -y numpy
# !pip install matplotlib
# !pip install pandas
# # !pip install sklearn
# !pip install keras
# # !pip install scikit-learn
# !pip install scikeras
#
# # !pip uninstall -y numpy
# #
# # !pip install numpy==1.23.0
#

# %%
import numpy as np
import matplotlib.pyplot as pl
import pandas as pd
from pandas import Series

from sklearn.preprocessing import MinMaxScaler
from tensorflow import keras
from keras.models import Sequential, Model
from keras.layers import Dense, LSTM, CuDNNLSTM
from sklearn.metrics import mean_squared_error, mean_absolute_error

import tensorflow as tf
# Out:
# 2023-07-03 16:21:45.509804: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-03 16:21:45.953316: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# print(tf.config.list_physical_devices('GPU'))
#
# if tf.test.gpu_device_name():
#     print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# else:
#     print("Please install GPU version of TF")

# %%
csv_path = 'inp/IBIRITE (ROLA MOCA)_MG.csv'

# %%
data = pd.read_csv(csv_path, sep=';')
data
# Out:
#             DATE     Chuva  $Pressão_{Inst}$  $Pressão_{Max}$  \
# 0     2008-06-06  0.000000        886.500000       886.533333
# 1     2008-06-07  0.000000        887.037500       887.250000
# 2     2008-06-08  0.000000        886.783333       886.983333
# 3     2008-06-09  0.000000        886.341667       886.516667
# 4     2008-06-10  0.000000        885.012500       885.220833
# ...          ...       ...               ...              ...
# 4792  2021-12-27  0.000000        880.675000       880.900000
# 4793  2021-12-28  0.983333        881.758333       882.012500
# 4794  2021-12-29  0.150000        883.337500       883.616667
# 4795  2021-12-30  1.008333        881.166667       881.458333
# 4796  2021-12-31  1.025000        879.704167       879.970833
#
#       $Pressão_{Min}$  $Temperatura_{Inst}$  $Orvalho_{Inst}$  \
# 0          886.300000             21.100000         10.500000
# 1          886.854167             19.458333         10.083333
# 2          886.583333             19.095833         10.504167
# 3          886.204167             18.700000         12.312500
# 4          884.820833             18.529167         11.920833
# ...               ...                   ...               ...
# 4792       880.425000             22.075000         14.425000
# 4793       881.445833             21.458333         15.970833
# 4794       883.075000             19.704167         16.345833
# 4795       880.958333             18.454167         16.762500
# 4796       879.454167             17.395833         16.145833
#
#       $Temperatura_{Max}$  $Temperatura_{Min}$  $Orvalho_{Max}$  ...  \
# 0               22.333333            20.900000        10.766667  ...
# 1               20.016667            18.770833        10.637500  ...
# 2               19.704167            18.458333        11.054167  ...
# 3               19.304167            18.079167        12.662500  ...
# 4               19.291667            17.795833        12.566667  ...
# ...                   ...                  ...              ...  ...
# 4792            22.783333            21.395833        15.054167  ...
# 4793            22.525000            20.708333        16.695833  ...
# 4794            20.341667            19.187500        16.850000  ...
# 4795            18.820833            18.204167        17.050000  ...
# 4796            17.770833            17.129167        16.479167  ...
#
#       $Umidade_{Min}$  $Umidade_{Inst}$  $Vento_{Dir}$  $Vento_{Raj}$  \
# 0           48.333333         51.666667      56.333333       6.233333
# 1           54.000000         56.458333      76.458333       6.604167
# 2           55.458333         58.750000      79.791667       8.570833
# 3           64.541667         67.583333     125.875000       7.779167
# 4           64.916667         67.833333     139.625000       4.750000
# ...               ...               ...            ...            ...
# 4792        60.291667         63.416667     174.083333       6.562500
# 4793        68.333333         72.875000     176.750000       7.200000
# 4794        78.791667         82.000000     131.375000       5.400000
# 4795        88.375000         89.875000      98.000000       5.812500
# 4796        90.833333         92.416667      37.333333      10.283333
#
#       $Vento_{Vel}$   GLOBAL   Latitude  Longitude  Altitude         Qo
# 0          3.133333   1.9223 -20.031457 -44.011249   1198.82   2.195897
# 1          3.537500  19.2513 -20.031457 -44.011249   1198.82  24.544495
# 2          4.383333  17.9175 -20.031457 -44.011249   1198.82  24.486118
# 3          4.033333  16.2483 -20.031457 -44.011249   1198.82  24.430901
# 4          2.329167  13.3562 -20.031457 -44.011249   1198.82  24.378872
# ...             ...      ...        ...        ...       ...        ...
# 4792       1.462500  26.3813 -20.031457 -44.011249   1198.82  42.703244
# 4793       1.875000  23.1625 -20.031457 -44.011249   1198.82  42.712820
# 4794       0.254167  18.4593 -20.031457 -44.011249   1198.82  42.718808
# 4795       1.733333   5.3534 -20.031457 -44.011249   1198.82  42.721202
# 4796       4.566667   7.7033 -20.031457 -44.011249   1198.82  42.719993
#
# [4797 rows x 22 columns]

# %%
data.rename(columns={"PRECIPITAÇÃO TOTAL, HORÁRIO (mm)": "Chuva",
                     "PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)": "$Pressão_{Inst}$",
                     "PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)": "$Pressão_{Max}$",
                     "PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)": "$Pressão_{Min}$",
                     "RADIACAO GLOBAL (KJ/m²)": "H",
                     "TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)": "$Temperatura_{Inst}$",
                     "TEMPERATURA DO PONTO DE ORVALHO (°C)": "$Orvalho_{Inst}$",
                     "TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)": "$Temperatura_{Max}$",
                     "TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)": "$Temperatura_{Min}$",
                     "TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)": "$Orvalho_{Max}$",
                     "TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)": "$Orvalho_{Min}$",
                     "UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)": "$Umidade_{Max}$",
                     "UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)": "$Umidade_{Min}$",
                     "UMIDADE RELATIVA DO AR, HORARIA (%)": "$Umidade_{Inst}$",
                     "VENTO, DIREÇÃO HORARIA (gr) (° (gr))": "$Vento_{Dir}$",
                     "VENTO, RAJADA MAXIMA (m/s)": "$Vento_{Raj}$",
                     "VENTO, VELOCIDADE HORARIA (m/s)": "$Vento_{Vel}$",
                     "RADIACAO GLOBAL (Kj/m²)": "GLOBAL"}, inplace=True)
data
# Out:
#             DATE     Chuva  $Pressão_{Inst}$  $Pressão_{Max}$  \
# 0     2008-06-06  0.000000        886.500000       886.533333
# 1     2008-06-07  0.000000        887.037500       887.250000
# 2     2008-06-08  0.000000        886.783333       886.983333
# 3     2008-06-09  0.000000        886.341667       886.516667
# 4     2008-06-10  0.000000        885.012500       885.220833
# ...          ...       ...               ...              ...
# 4792  2021-12-27  0.000000        880.675000       880.900000
# 4793  2021-12-28  0.983333        881.758333       882.012500
# 4794  2021-12-29  0.150000        883.337500       883.616667
# 4795  2021-12-30  1.008333        881.166667       881.458333
# 4796  2021-12-31  1.025000        879.704167       879.970833
#
#       $Pressão_{Min}$  $Temperatura_{Inst}$  $Orvalho_{Inst}$  \
# 0          886.300000             21.100000         10.500000
# 1          886.854167             19.458333         10.083333
# 2          886.583333             19.095833         10.504167
# 3          886.204167             18.700000         12.312500
# 4          884.820833             18.529167         11.920833
# ...               ...                   ...               ...
# 4792       880.425000             22.075000         14.425000
# 4793       881.445833             21.458333         15.970833
# 4794       883.075000             19.704167         16.345833
# 4795       880.958333             18.454167         16.762500
# 4796       879.454167             17.395833         16.145833
#
#       $Temperatura_{Max}$  $Temperatura_{Min}$  $Orvalho_{Max}$  ...  \
# 0               22.333333            20.900000        10.766667  ...
# 1               20.016667            18.770833        10.637500  ...
# 2               19.704167            18.458333        11.054167  ...
# 3               19.304167            18.079167        12.662500  ...
# 4               19.291667            17.795833        12.566667  ...
# ...                   ...                  ...              ...  ...
# 4792            22.783333            21.395833        15.054167  ...
# 4793            22.525000            20.708333        16.695833  ...
# 4794            20.341667            19.187500        16.850000  ...
# 4795            18.820833            18.204167        17.050000  ...
# 4796            17.770833            17.129167        16.479167  ...
#
#       $Umidade_{Min}$  $Umidade_{Inst}$  $Vento_{Dir}$  $Vento_{Raj}$  \
# 0           48.333333         51.666667      56.333333       6.233333
# 1           54.000000         56.458333      76.458333       6.604167
# 2           55.458333         58.750000      79.791667       8.570833
# 3           64.541667         67.583333     125.875000       7.779167
# 4           64.916667         67.833333     139.625000       4.750000
# ...               ...               ...            ...            ...
# 4792        60.291667         63.416667     174.083333       6.562500
# 4793        68.333333         72.875000     176.750000       7.200000
# 4794        78.791667         82.000000     131.375000       5.400000
# 4795        88.375000         89.875000      98.000000       5.812500
# 4796        90.833333         92.416667      37.333333      10.283333
#
#       $Vento_{Vel}$   GLOBAL   Latitude  Longitude  Altitude         Qo
# 0          3.133333   1.9223 -20.031457 -44.011249   1198.82   2.195897
# 1          3.537500  19.2513 -20.031457 -44.011249   1198.82  24.544495
# 2          4.383333  17.9175 -20.031457 -44.011249   1198.82  24.486118
# 3          4.033333  16.2483 -20.031457 -44.011249   1198.82  24.430901
# 4          2.329167  13.3562 -20.031457 -44.011249   1198.82  24.378872
# ...             ...      ...        ...        ...       ...        ...
# 4792       1.462500  26.3813 -20.031457 -44.011249   1198.82  42.703244
# 4793       1.875000  23.1625 -20.031457 -44.011249   1198.82  42.712820
# 4794       0.254167  18.4593 -20.031457 -44.011249   1198.82  42.718808
# 4795       1.733333   5.3534 -20.031457 -44.011249   1198.82  42.721202
# 4796       4.566667   7.7033 -20.031457 -44.011249   1198.82  42.719993
#
# [4797 rows x 22 columns]

# %%
data.set_index('DATE', inplace=True)
data.dropna(axis=0, how='all', subset=None, inplace=True)
data.dropna(axis=1, how='all', subset=None, inplace=True)

# %%
#DEPENDENDO DO ANO E DA ESTAÇÃO OS VALORES DE RADIAÇÃO ESTÃO EM COLUNAS DIFERENTES
if 'GLOBAL' not in data.columns:
    data.rename(columns={"H": "GLOBAL"}, inplace=True)
if 'H' in data.columns:
    data['GLOBAL'].fillna(data['H'], inplace=True)
    data.drop(['H'], axis=1, inplace=True)

# %%
train_dates = pd.to_datetime(data.index)

data = data[
    ['$Temperatura_{Inst}$', '$Temperatura_{Max}$', '$Temperatura_{Min}$', '$Umidade_{Max}$', '$Umidade_{Min}$',
     '$Umidade_{Inst}$', 'GLOBAL']]

cols = list(data)[0:7]
data = data[cols].astype(float)
data
# Out:
#             $Temperatura_{Inst}$  $Temperatura_{Max}$  $Temperatura_{Min}$  \
# DATE
# 2008-06-06             21.100000            22.333333            20.900000
# 2008-06-07             19.458333            20.016667            18.770833
# 2008-06-08             19.095833            19.704167            18.458333
# 2008-06-09             18.700000            19.304167            18.079167
# 2008-06-10             18.529167            19.291667            17.795833
# ...                          ...                  ...                  ...
# 2021-12-27             22.075000            22.783333            21.395833
# 2021-12-28             21.458333            22.525000            20.708333
# 2021-12-29             19.704167            20.341667            19.187500
# 2021-12-30             18.454167            18.820833            18.204167
# 2021-12-31             17.395833            17.770833            17.129167
#
#             $Umidade_{Max}$  $Umidade_{Min}$  $Umidade_{Inst}$   GLOBAL
# DATE
# 2008-06-06        52.333333        48.333333         51.666667   1.9223
# 2008-06-07        59.333333        54.000000         56.458333  19.2513
# 2008-06-08        61.333333        55.458333         58.750000  17.9175
# 2008-06-09        69.916667        64.541667         67.583333  16.2483
# 2008-06-10        71.625000        64.916667         67.833333  13.3562
# ...                     ...              ...               ...      ...
# 2021-12-27        66.375000        60.291667         63.416667  26.3813
# 2021-12-28        76.458333        68.333333         72.875000  23.1625
# 2021-12-29        84.708333        78.791667         82.000000  18.4593
# 2021-12-30        90.833333        88.375000         89.875000   5.3534
# 2021-12-31        93.500000        90.833333         92.416667   7.7033
#
# [4797 rows x 7 columns]

# %%
# GARANTINDO QUE TODOS OS DADOS ESTÃO SENDO TRATADOS COMO FLOAT
data = data.replace(',', '.', regex=True)
data['$Temperatura_{Inst}$'] = data['$Temperatura_{Inst}$'].astype(float)
data['$Temperatura_{Max}$'] = data['$Temperatura_{Max}$'].astype(float)
data['$Temperatura_{Min}$'] = data['$Temperatura_{Min}$'].astype(float)
data['GLOBAL'] = data['GLOBAL'].astype(float)

# %%
#DELETANDO ALGUMA LEITURA ONDE O MÁXIMO É MENOR QUE O MÍNIMO
delIndex = data.loc[(data['$Temperatura_{Max}$'] < data['$Temperatura_{Min}$']) | (
        data['$Umidade_{Max}$'] < data['$Umidade_{Min}$'])].index
if len(delIndex) > 0:
    data.drop(delIndex, axis=0, inplace=True)

# %%
#DELETANDO ALGUMA LEITURA ONDE O MÁXIMO É MENOR QUE O INSTANTÂNEO
delIndex = data.loc[(data['$Temperatura_{Max}$'] < data['$Temperatura_{Inst}$']) | (
        data['$Umidade_{Max}$'] < data['$Umidade_{Inst}$'])].index
if len(delIndex) > 0:
    data.drop(delIndex, axis=0, inplace=True)

# %%
#DELETANDO ALGUMA LEITURA ONDE O INSTANTÂNEO É MENOR QUE O MÍNIMO
delIndex = data.loc[(data['$Temperatura_{Inst}$'] < data['$Temperatura_{Min}$']) | (
        data['$Umidade_{Inst}$'] < data['$Umidade_{Min}$'])].index
if len(delIndex) > 0:
    data.drop(delIndex, axis=0, inplace=True)

# %%
# #MODIFICANDO A UNIDADE DA RADIAÇÃO DE (Kj/m²) PARA (Mj/m²)
data['GLOBAL'] = data['GLOBAL'].mul(0.001)

# %%
#DELETANDO ALGUMA LINHA QUE AINDA TENHA NAN
data.dropna(inplace=True)

# %%
# EXTRAINDO OS NOMES DAS COLUNAS
target_names = ['GLOBAL']
variable_names = data.columns.values
variable_names = np.delete(variable_names, np.where(variable_names == target_names))

# %%
date_range = data.index

var_to_plot = data.columns
df = data[var_to_plot]

n = int(df.shape[0] * 0.7)
df.index = range(df.shape[0])
id0 = df.index <= n
id1 = df.index > n
print(data.index)

# pl.rc('text', usetex=False)
# # pl.rc('font', family='serif',  serif='Times')
# pl.rc('xtick', labelsize=20)
# pl.rc('ytick', labelsize=20)
# fig=pl.figure(figsize=(18,24))
# for i,group in enumerate(data.columns):
#     sub=pl.subplot(len(data.columns), 1, i+1)
#     data[group].iloc[id0].plot( marker='', label='Training')#,fontsize=16,)#pyplot.plot(dataset[group].values)
#     data[group].iloc[id1].plot( marker='', label='Test')#,fontsize=16,)#pyplot.plot(dataset[group].values)
#     data[data.columns[i]].plot(marker='', lw=0)
# #         pl.axvline(n, color='k', ls='-.')
#     pl.ylabel(group,rotation = 0, fontsize=20,)
#     sub.yaxis.tick_right()#COLOCANDO OS TICKS NA DIREITA
#     sub.yaxis.set_label_coords(-0.05,0.5)#AJUSTANDO A POSIÇÃO DOS LABELS PARA NÃO SOBRESCREVER O PLOT
# fig.autofmt_xdate(rotation=30)

# pl.show()
# Out:
# Index(['2008-06-06', '2008-06-07', '2008-06-08', '2008-06-09', '2008-06-10',
#        '2008-06-11', '2008-06-12', '2008-06-13', '2008-06-14', '2008-06-15',
#        ...
#        '2021-12-22', '2021-12-23', '2021-12-24', '2021-12-25', '2021-12-26',
#        '2021-12-27', '2021-12-28', '2021-12-29', '2021-12-30', '2021-12-31'],
#       dtype='object', name='DATE', length=4797)

# %%
# import seaborn as sns

# df = X.copy()

# df[target_names] = y.values
# corr = df.corr()
# mask = np.triu(np.ones_like(corr, dtype=bool))
# f, ax = pl.subplots(figsize=(11, 9))
# cmap = sns.diverging_palette(230, 20, as_cmap=True)
# cmap = cmap = "YlGnBu"
# sns.heatmap(corr, mask=mask, cmap=cmap,  #vmax=.3, center=0,
#             annot=True,  #fmt="d")
#             square=True, linewidths=.5,  #cbar_kws={"shrink": .5},
#             )
# pl.show()

# %%
X = data[variable_names]
y = data[target_names]

# %%
from sklearn.preprocessing import StandardScaler
# normalizing the data
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(-1, 1))
data = scaler.fit_transform(data)

# scaler = StandardScaler()
# scaler = scaler.fit(X)
# X = scaler.transform(X)
data
# Out:
# array([[ 0.15504838,  0.20013506,  0.22434721, ..., -0.28418803,
#         -0.25979843, -0.98624192],
#        [-0.04043662, -0.06972229, -0.03386684, ..., -0.13888889,
#         -0.13101904,  0.13202141],
#        [-0.08360208, -0.10612391, -0.07176518, ..., -0.10149573,
#         -0.06942889,  0.04594953],
#        ...,
#        [-0.01116348, -0.03186461,  0.01666429, ...,  0.49679487,
#          0.55543113,  0.0809126 ],
#        [-0.16000992, -0.20901916, -0.10258917, ...,  0.74252137,
#          0.76707727, -0.76482849],
#        [-0.28603324, -0.33132861, -0.23295948, ...,  0.80555556,
#          0.83538634, -0.61318633]])

# %%
print(X)
# Out:
#             $Temperatura_{Inst}$  $Temperatura_{Max}$  $Temperatura_{Min}$  \
# DATE
# 2008-06-06             21.100000            22.333333            20.900000
# 2008-06-07             19.458333            20.016667            18.770833
# 2008-06-08             19.095833            19.704167            18.458333
# 2008-06-09             18.700000            19.304167            18.079167
# 2008-06-10             18.529167            19.291667            17.795833
# ...                          ...                  ...                  ...
# 2021-12-27             22.075000            22.783333            21.395833
# 2021-12-28             21.458333            22.525000            20.708333
# 2021-12-29             19.704167            20.341667            19.187500
# 2021-12-30             18.454167            18.820833            18.204167
# 2021-12-31             17.395833            17.770833            17.129167
#
#             $Umidade_{Max}$  $Umidade_{Min}$  $Umidade_{Inst}$
# DATE
# 2008-06-06        52.333333        48.333333         51.666667
# 2008-06-07        59.333333        54.000000         56.458333
# 2008-06-08        61.333333        55.458333         58.750000
# 2008-06-09        69.916667        64.541667         67.583333
# 2008-06-10        71.625000        64.916667         67.833333
# ...                     ...              ...               ...
# 2021-12-27        66.375000        60.291667         63.416667
# 2021-12-28        76.458333        68.333333         72.875000
# 2021-12-29        84.708333        78.791667         82.000000
# 2021-12-30        90.833333        88.375000         89.875000
# 2021-12-31        93.500000        90.833333         92.416667
#
# [4797 rows x 6 columns]

# %%
from sklearn.model_selection import train_test_split

train_x = []
train_y = []

n_future = 1
n_past = 3

for i in range(n_past, len(data) - n_future + 1):
    train_x.append(data[i - n_past:i, 0:data.shape[1]])
    train_y.append(data[i + n_future - 1:i + n_future, 0])

train_x = np.array(train_x)
train_y = np.array(train_y)

# Separar os dados em conjuntos de treinamento e teste
train_x, test_x, train_y, test_y = train_test_split(train_x, train_y, test_size=0.15, random_state=42)

print("Shape de train_x:", train_x.shape)
print("Shape de train_y:", train_y.shape)
print("Shape de test_x:", test_x.shape)
print("Shape de test_y:", test_y.shape)
# Out:
# Shape de train_x: (4074, 3, 7)
# Shape de train_y: (4074, 1)
# Shape de test_x: (720, 3, 7)
# Shape de test_y: (720, 1)

# %%
# # split the data for training and test, for training a want 70% of the data, and i need split the data in n_past_days=3 and n_future_days=1
#
# n_past = 3
# n_future = 1
#
# total_samples = len(X)
# n_samples = total_samples - (n_past - n_future) + 1
#
# train_size = int(n_samples * 0.7)
# train_x, test_x = X[:train_size], X[train_size:]
# train_y, test_y = y[:train_size], y[train_size:]
#
# # reshape
# train_x = [train_x[i:i + n_past] for i in range(train_size - n_past + 1)]
# test_x = [test_x[i:i + n_past] for i in range(len(test_x) - n_past + 1)]
# train_y = train_y[n_past - 1:train_size + n_future - 1]
# test_y = test_y[n_past - 1:]
#
# train_x, train_y = np.array(train_x), np.array(train_y)
# test_x, test_y = np.array(test_x), np.array(test_y)
#
# train_x.shape, train_y.shape, test_x.shape, test_y.shape

# %%
# from tensorflow import keras
# from tensorflow.keras.models import Sequential, Model
# from tensorflow.keras.layers import *
# from tensorflow.keras.callbacks import ModelCheckpoint
# from tensorflow.keras.losses import MeanSquaredError
# from tensorflow.keras.metrics import mean_squared_error, mean_absolute_error, RootMeanSquaredError
# from tensorflow.keras.optimizers import Adam
#
# params = {
#     'batch_size': [32],
#     'epochs': [100],
#     'optimizer': ['adam'],
#     'learning_rate': [0.01],
#     'activation': ['relu'],
#     'dropout': [0.1],
#     'neurons': [5]
# }
#
#
# def create_model(learning_rate=0.1, optimizer='adam', activation='relu', dropout=0.1, neurons=1):
#     model1 = Sequential()
#     model1.add(CuDNNLSTM(neurons, input_shape=(train_x.shape[1], train_x.shape[2]), return_sequences=False))
#     # model1.add(Dropout(dropout))
#     model1.add(Dense(train_y.shape[1]))
#     model1.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=learning_rate),
#                    metrics=[RootMeanSquaredError()])
#     return model1
#
#
# from scikeras.wrappers import KerasRegressor
# from evolutionary_search import EvolutionaryAlgorithmSearchCV
#
# model = KerasRegressor(model=create_model, verbose=2, learning_rate=[0.01], activation=['relu'],
#                        dropout=[0.1], neurons=[5])
#
# # define checkpoint callback
# checkpoint = ModelCheckpoint('best_model.h5', monitor='val_loss', verbose=1, save_best_only=True, mode='min')
#
# eas = EvolutionaryAlgorithmSearchCV(estimator=model,
#                                     params=params,
#                                     scoring='neg_mean_squared_error',
#                                     cv=3,
#                                     verbose=1,
#                                     population_size=50,
#                                     gene_mutation_prob=0.01,
#                                     gene_crossover_prob=0.8,
#                                     tournament_size=3,
#                                     generations_number=5)
#
# eas.fit(train_x, train_y)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.metrics import RootMeanSquaredError
from scikeras.wrappers import KerasRegressor
from evolutionary_search import EvolutionaryAlgorithmSearchCV

params = {
    'batch_size': [1024],
    'epochs': [100, 200],
    'optimizer': ['adam', 'sgd'],
    'learning_rate': [0.01, 0.001],
    'activation': ['relu', 'sigmoid'],
    'dropout': [0.2, 0.4],
    'neurons': [32, 64]
}


def create_model(learning_rate=0.1, optimizer='adam', activation='relu', dropout=0.1, neurons=1):
    model1 = Sequential()
    model1.add(CuDNNLSTM(neurons, input_shape=(train_x.shape[1], train_x.shape[2]), return_sequences=True))
    model1.add(CuDNNLSTM(int(neurons/2), return_sequences=False))
    model1.add(Dense(train_y.shape[1]))
    model1.add(Dropout(dropout))
    if optimizer == 'adam':
        optimizer = Adam(learning_rate=learning_rate)
    elif optimizer == 'sgd':
        optimizer = SGD(learning_rate=learning_rate)
    model1.compile(loss=MeanSquaredError(), optimizer=optimizer,
                   metrics=[RootMeanSquaredError()])
    return model1


model = KerasRegressor(model=create_model, verbose=2, learning_rate=[0.01, 0.001], activation=['relu', 'sigmoid'],
                       dropout=[0.2, 0.4], neurons=[32, 64])

checkpoint = ModelCheckpoint('best_model.h5', monitor='val_loss', verbose=1, save_best_only=True, mode='min')

eas = EvolutionaryAlgorithmSearchCV(estimator=model,
                                    params=params,
                                    scoring='neg_mean_squared_error',
                                    cv=3,
                                    verbose=1,
                                    population_size=50,
                                    gene_mutation_prob=0.01,
                                    gene_crossover_prob=0.8,
                                    tournament_size=3,
                                    generations_number=15)

# Enable graph execution mode
tf.config.run_functions_eagerly(True)
# tf.config.run_functions_eagerly(False)

# Fit the model
eas.fit(train_x, train_y)
# Out:
# Types [1, 1, 1, 2, 1, 2, 1] and maxint [0, 1, 1, 1, 1, 1, 1] detected
# --- Evolve in 64 possible combinations ---
# 2023-07-03 16:21:46.818574: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000
ms/step
# Epoch 3/200
# 3/3 - 0s - loss: 0.0466 - root_mean_squared_error: 0.2159 - 176ms/epoch - 59ms/step
# Epoch 4/200
# 3/3 - 0s - loss: 0.0428 - root_mean_squared_error: 0.2068 - 182ms/epoch - 61ms/step
# Epoch 5/200
# 3/3 - 0s - loss: 0.0379 - root_mean_squared_error: 0.1947 - 165ms/epoch - 55ms/step
# Epoch 6/200
# 3/3 - 0s - loss: 0.0377 - root_mean_squared_error: 0.1940 - 164ms/epoch - 55ms/step
# Epoch 7/200
# 3/3 - 0s - loss: 0.0384 - root_mean_squared_error: 0.1959 - 162ms/epoch - 54ms/step
# Epoch 8/200
# 3/3 - 0s - loss: 0.0334 - root_mean_squared_error: 0.1828 - 162ms/epoch - 54ms/step
# Epoch 9/200
# 3/3 - 0s - loss: 0.0346 - root_mean_squared_error: 0.1860 - 153ms/epoch - 51ms/step
# Epoch 10/200
# 3/3 - 0s - loss: 0.0328 - root_mean_squared_error: 0.1810 - 161ms/epoch - 54ms/step
# Epoch 11/200
# 3/3 - 0s - loss: 0.0325 - root_mean_squared_error: 0.1804 - 159ms/epoch - 53ms/step
# Epoch 12/200
# 3/3 - 0s - loss: 0.0318 - root_mean_squared_error: 0.1784 - 169ms/epoch - 56ms/step
# Epoch 13/200
# 3/3 - 0s - loss: 0.0307 - root_mean_squared_error: 0.1753 - 158ms/epoch - 53ms/step
# Epoch 14/200
# 3/3 - 0s - loss: 0.0323 - root_mean_squared_error: 0.1797 - 166ms/epoch - 55ms/step
# Epoch 15/200
# 3/3 - 0s - loss: 0.0327 - root_mean_squared_error: 0.1809 - 168ms/epoch - 56ms/step
# Epoch 16/200
# 3/3 - 0s - loss: 0.0309 - root_mean_squared_error: 0.1759 - 160ms/epoch - 53ms/step
# Epoch 17/200
# 3/3 - 0s - loss: 0.0292 - root_mean_squared_error: 0.1710 - 162ms/epoch - 54ms/step
# Epoch 18/200
# 3/3 - 0s - loss: 0.0317 - root_mean_squared_error: 0.1781 - 161ms/epoch - 54ms/step
# Epoch 19/200
# 3/3 - 0s - loss: 0.0328 - root_mean_squared_error: 0.1810 - 162ms/epoch - 54ms/step
# Epoch 20/200
# 3/3 - 0s - loss: 0.0304 - root_mean_squared_error: 0.1745 - 158ms/epoch - 53ms/step
# Epoch 21/200
# 3/3 - 0s - loss: 0.0306 - root_mean_squared_error: 0.1750 - 160ms/epoch - 53ms/step
# Epoch 22/200
# 3/3 - 0s - loss: 0.0320 - root_mean_squared_error: 0.1789 - 171ms/epoch - 57ms/step
# Epoch 23/200
# 3/3 - 0s - loss: 0.0302 - root_mean_squared_error: 0.1737 - 159ms/epoch - 53ms/step
# Epoch 24/200
# 3/3 - 0s - loss: 0.0315 - root_mean_squared_error: 0.1775 - 162ms/epoch - 54ms/step
# Epoch 25/200
# 3/3 - 0s - loss: 0.0320 - root_mean_squared_error: 0.1789 - 163ms/epoch - 54ms/step
# Epoch 26/200
# 3/3 - 0s - loss: 0.0312 - root_mean_squared_error: 0.1766 - 160ms/epoch - 53ms/step
# Epoch 27/200
# 3/3 - 0s - loss: 0.0308 - root_mean_squared_error: 0.1754 - 160ms/epoch - 53ms/step
# Epoch 28/200
# 3/3 - 0s - loss: 0.0314 - root_mean_squared_error: 0.1771 - 152ms/epoch - 51ms/step
# Epoch 29/200
# 3/3 - 0s - loss: 0.0332 - root_mean_squared_error: 0.1823 - 159ms/epoch - 53ms/step
# Epoch 30/200
# 3/3 - 0s - loss: 0.0325 - root_mean_squared_error: 0.1803 - 161ms/epoch - 54ms/step
# Epoch 31/200
# 3/3 - 0s - loss: 0.0319 - root_mean_squared_error: 0.1785 - 171ms/epoch - 57ms/step
# Epoch 32/200
# 3/3 - 0s - loss: 0.0313 - root_mean_squared_error: 0.1770 - 160ms/epoch - 53ms/step
# Epoch 33/200
# 3/3 - 0s - loss: 0.0306 - root_mean_squared_error: 0.1748 - 156ms/epoch - 52ms/step
# Epoch 34/200
# 3/3 - 0s - loss: 0.0322 - root_mean_squared_error: 0.1793 - 155ms/epoch - 52ms/step
# Epoch 35/200
# 3/3 - 0s - loss: 0.0306 - root_mean_squared_error: 0.1749 - 160ms/epoch - 53ms/step
# Epoch 36/200
# 3/3 - 0s - loss: 0.0307 - root_mean_squared_error: 0.1752 - 163ms/epoch - 54ms/step
# Epoch 37/200
# 3/3 - 0s - loss: 0.0310 - root_mean_squared_error: 0.1762 - 154ms/epoch - 51ms/step
# Epoch 38/200
# 3/3 - 0s - loss: 0.0314 - root_mean_squared_error: 0.1772 - 167ms/epoch - 56ms/step
# Epoch 39/200
# 3/3 - 0s - loss: 0.0312 - root_mean_squared_error: 0.1765 - 156ms/epoch - 52ms/step
# Epoch 40/200
# 3/3 - 0s - loss: 0.0320 - root_mean_squared_error: 0.1789 - 189ms/epoch - 63ms/step
# Epoch 41/200
# 3/3 - 0s - loss: 0.0314 - root_mean_squared_error: 0.1771 - 180ms/epoch - 60ms/step
# Epoch 42/200
# ...
# 4/4 - 0s - loss: 0.0348 - root_mean_squared_error: 0.1866 - 204ms/epoch - 51ms/step
# Epoch 38/200
# 4/4 - 0s - loss: 0.0335 - root_mean_squared_error: 0.1830 - 218ms/epoch - 54ms/step
# Epoch 39/200
# 4/4 - 0s - loss: 0.0332 - root_mean_squared_error: 0.1822 - 210ms/epoch - 52ms/step
# Epoch 40/200
# 4/4 - 0s - loss: 0.0347 - root_mean_squared_error: 0.1862 - 205ms/epoch - 51ms/step
# Epoch 41/200
# 4/4 - 0s - loss: 0.0335 - root_mean_squared_error: 0.1831 - 207ms/epoch - 52ms/step
# Epoch 42/200
# 4/4 - 0s - loss: 0.0321 - root_mean_squared_error: 0.1791 - 202ms/epoch - 50ms/step
# Epoch 43/200
# 4/4 - 0s - loss: 0.0325 - root_mean_squared_error: 0.1803 - 199ms/epoch - 50ms/step
# Epoch 44/200
# 4/4 - 0s - loss: 0.0339 - root_mean_squared_error: 0.1842 - 210ms/epoch - 53ms/step
# Epoch 45/200
# 4/4 - 0s - loss: 0.0327 - root_mean_squared_error: 0.1808 - 215ms/epoch - 54ms/step
# Epoch 46/200
# 4/4 - 0s - loss: 0.0322 - root_mean_squared_error: 0.1795 - 209ms/epoch - 52ms/step
# Epoch 47/200
# 4/4 - 0s - loss: 0.0334 - root_mean_squared_error: 0.1828 - 209ms/epoch - 52ms/step
# Epoch 48/200
# 4/4 - 0s - loss: 0.0330 - root_mean_squared_error: 0.1816 - 208ms/epoch - 52ms/step
# Epoch 49/200
# 4/4 - 0s - loss: 0.0312 - root_mean_squared_error: 0.1766 - 217ms/epoch - 54ms/step
# Epoch 50/200
# 4/4 - 0s - loss: 0.0337 - root_mean_squared_error: 0.1837 - 201ms/epoch - 50ms/step
# Epoch 51/200
# 4/4 - 0s - loss: 0.0318 - root_mean_squared_error: 0.1783 - 196ms/epoch - 49ms/step
# Epoch 52/200
# 4/4 - 0s - loss: 0.0332 - root_mean_squared_error: 0.1823 - 210ms/epoch - 52ms/step
# Epoch 53/200
# 4/4 - 0s - loss: 0.0331 - root_mean_squared_error: 0.1819 - 209ms/epoch - 52ms/step
# Epoch 54/200
# 4/4 - 0s - loss: 0.0319 - root_mean_squared_error: 0.1786 - 209ms/epoch - 52ms/step
# Epoch 55/200
# 4/4 - 0s - loss: 0.0314 - root_mean_squared_error: 0.1771 - 221ms/epoch - 55ms/step
# Epoch 56/200
# 4/4 - 0s - loss: 0.0317 - root_mean_squared_error: 0.1781 - 212ms/epoch - 53ms/step
# Epoch 57/200
# 4/4 - 0s - loss: 0.0318 - root_mean_squared_error: 0.1783 - 209ms/epoch - 52ms/step
# Epoch 58/200
# 4/4 - 0s - loss: 0.0312 - root_mean_squared_error: 0.1767 - 208ms/epoch - 52ms/step
# Epoch 59/200
# 4/4 - 0s - loss: 0.0315 - root_mean_squared_error: 0.1774 - 207ms/epoch - 52ms/step
# Epoch 60/200
# 4/4 - 0s - loss: 0.0320 - root_mean_squared_error: 0.1789 - 254ms/epoch - 64ms/step
# Epoch 61/200
# 4/4 - 0s - loss: 0.0303 - root_mean_squared_error: 0.1740 - 225ms/epoch - 56ms/step
# Epoch 62/200
# 4/4 - 0s - loss: 0.0312 - root_mean_squared_error: 0.1767 - 215ms/epoch - 54ms/step
# Epoch 63/200
# 4/4 - 0s - loss: 0.0317 - root_mean_squared_error: 0.1780 - 228ms/epoch - 57ms/step
# Epoch 64/200
# 4/4 - 0s - loss: 0.0328 - root_mean_squared_error: 0.1810 - 238ms/epoch - 59ms/step
# Epoch 65/200
# 4/4 - 0s - loss: 0.0330 - root_mean_squared_error: 0.1818 - 229ms/epoch - 57ms/step
# Epoch 66/200
# 4/4 - 0s - loss: 0.0333 - root_mean_squared_error: 0.1825 - 239ms/epoch - 60ms/step
# Epoch 67/200
# 4/4 - 0s - loss: 0.0325 - root_mean_squared_error: 0.1803 - 217ms/epoch - 54ms/step
# Epoch 68/200
# 4/4 - 0s - loss: 0.0315 - root_mean_squared_error: 0.1775 - 222ms/epoch - 55ms/step
# Epoch 69/200
# 4/4 - 0s - loss: 0.0306 - root_mean_squared_error: 0.1749 - 220ms/epoch - 55ms/step
# Epoch 70/200
# 4/4 - 0s - loss: 0.0313 - root_mean_squared_error: 0.1769 - 227ms/epoch - 57ms/step
# Epoch 71/200
# 4/4 - 0s - loss: 0.0314 - root_mean_squared_error: 0.1771 - 240ms/epoch - 60ms/step
# Epoch 72/200
# 4/4 - 0s - loss: 0.0317 - root_mean_squared_error: 0.1781 - 236ms/epoch - 59ms/step
# Epoch 73/200
# 4/4 - 0s - loss: 0.0310 - root_mean_squared_error: 0.1761 - 211ms/epoch - 53ms/step
# Epoch 74/200
# 4/4 - 0s - loss: 0.0320 - root_mean_squared_error: 0.1790 - 220ms/epoch - 55ms/step
# Epoch 75/200
# 4/4 - 0s - loss: 0.0316 - root_mean_squared_error: 0.1779 - 256ms/epoch - 64ms/step
# Epoch 76/200
# 4/4 - 0s - loss: 0.0329 - root_mean_squared_error: 0.1813 - 219ms/epoch - 55ms/step
# Epoch 77/200
# 4/4 - 0s - loss: 0.0316 - root_mean_squared_error: 0.1779 - 205ms/epoch - 51ms/step
# Epoch 78/200
# 4/4 - 0s - loss: 0.0308 - root_mean_squared_error: 0.1754 - 208ms/epoch - 52ms/step
# Epoch 79/200
# 4/4 - 0s - loss: 0.0307 - root_mean_squared_error: 0.1754 - 233ms/epoch - 58ms/step
# Epoch 80/200
# 4/4 - 0s - loss: 0.0323 - root_mean_squared_error: 0.1796 - 233ms/epoch - 58ms/step
# Epoch 81/200
# 4/4 - 0s - loss: 0.0317 - root_mean_squared_error: 0.1780 - 208ms/epoch - 52ms/step
# Epoch 82/200
# 4/4 - 0s - loss: 0.0305 - root_mean_squared_error: 0.1747 - 204ms/epoch - 51ms/step
# Epoch 83/200
# 4/4 - 0s - loss: 0.0308 - root_mean_squared_error: 0.1755 - 203ms/epoch - 51ms/step
# Epoch 84/200
# 4/4 - 0s - loss: 0.0297 - root_mean_squared_error: 0.1723 - 209ms/epoch - 52ms/step
# Epoch 85/200
# 4/4 - 0s - loss: 0.0313 - root_mean_squared_error: 0.1770 - 209ms/epoch - 52ms/step
# Epoch 86/200
# 4/4 - 0s - loss: 0.0312 - root_mean_squared_error: 0.1765 - 217ms/epoch - 54ms/step
# Epoch 87/200
# 4/4 - 0s - loss: 0.0325 - root_mean_squared_error: 0.1803 - 216ms/epoch - 54ms/step
# Epoch 88/200
# 4/4 - 0s - loss: 0.0314 - root_mean_squared_error: 0.1773 - 207ms/epoch - 52ms/step
# Epoch 89/200
# 4/4 - 0s - loss: 0.0317 - root_mean_squared_error: 0.1779 - 214ms/epoch - 54ms/step
# Epoch 90/200
# 4/4 - 0s - loss: 0.0312 - root_mean_squared_error: 0.1767 - 207ms/epoch - 52ms/step
# Epoch 91/200
# 4/4 - 0s - loss: 0.0321 - root_mean_squared_error: 0.1790 - 208ms/epoch - 52ms/step
# Epoch 92/200
# 4/4 - 0s - loss: 0.0322 - root_mean_squared_error: 0.1795 - 215ms/epoch - 54ms/step
# Epoch 93/200
# 4/4 - 0s - loss: 0.0319 - root_mean_squared_error: 0.1787 - 203ms/epoch - 51ms/step
# Epoch 94/200
# 4/4 - 0s - loss: 0.0325 - root_mean_squared_error: 0.1802 - 212ms/epoch - 53ms/step
# Epoch 95/200
# 4/4 - 0s - loss: 0.0320 - root_mean_squared_error: 0.1790 - 206ms/epoch - 52ms/step
# Epoch 96/200
# 4/4 - 0s - loss: 0.0317 - root_mean_squared_error: 0.1781 - 213ms/epoch - 53ms/step
# Epoch 97/200
# 4/4 - 0s - loss: 0.0312 - root_mean_squared_error: 0.1766 - 212ms/epoch - 53ms/step
# Epoch 98/200
# 4/4 - 0s - loss: 0.0307 - root_mean_squared_error: 0.1751 - 209ms/epoch - 52ms/step
# Epoch 99/200
# 4/4 - 0s - loss: 0.0314 - root_mean_squared_error: 0.1771 - 201ms/epoch - 50ms/step
# Epoch 100/200
# 4/4 - 0s - loss: 0.0327 - root_mean_squared_error: 0.1807 - 204ms/epoch - 51ms/step
# Epoch 101/200
# 4/4 - 0s - loss: 0.0305 - root_mean_squared_error: 0.1747 - 206ms/epoch - 52ms/step
# Epoch 102/200
# 4/4 - 0s - loss: 0.0307 - root_mean_squared_error: 0.1751 - 215ms/epoch - 54ms/step
# Epoch 103/200
# 4/4 - 0s - loss: 0.0313 - root_mean_squared_error: 0.1770 - 208ms/epoch - 52ms/step
# Epoch 104/200
# 4/4 - 0s - loss: 0.0307 - root_mean_squared_error: 0.1751 - 216ms/epoch - 54ms/step
# Epoch 105/200
# 4/4 - 0s - loss: 0.0318 - root_mean_squared_error: 0.1783 - 209ms/epoch - 52ms/step
# Epoch 106/200
# 4/4 - 0s - loss: 0.0320 - root_mean_squared_error: 0.1790 - 201ms/epoch - 50ms/step
# Epoch 107/200
# 4/4 - 0s - loss: 0.0316 - root_mean_squared_error: 0.1779 - 226ms/epoch - 56ms/step
# Epoch 108/200
# 4/4 - 0s - loss: 0.0326 - root_mean_squared_error: 0.1805 - 218ms/epoch - 54ms/step
# Epoch 109/200
# 4/4 - 0s - loss: 0.0315 - root_mean_squared_error: 0.1776 - 228ms/epoch - 57ms/step
# Epoch 110/200
# 4/4 - 0s - loss: 0.0307 - root_mean_squared_error: 0.1752 - 230ms/epoch - 57ms/step
# Epoch 111/200
# 4/4 - 0s - loss: 0.0309 - root_mean_squared_error: 0.1757 - 224ms/epoch - 56ms/step
# Epoch 112/200
# 4/4 - 0s - loss: 0.0341 - root_mean_squared_error: 0.1845 - 244ms/epoch - 61ms/step
# Epoch 113/200
# 4/4 - 0s - loss: 0.0313 - root_mean_squared_error: 0.1769 - 236ms/epoch - 59ms/step
# Epoch 114/200
# 4/4 - 0s - loss: 0.0321 - root_mean_squared_error: 0.1793 - 233ms/epoch - 58ms/step
# Epoch 115/200
# 4/4 - 0s - loss: 0.0297 - root_mean_squared_error: 0.1724 - 208ms/epoch - 52ms/step
# Epoch 116/200
# 4/4 - 0s - loss: 0.0320 - root_mean_squared_error: 0.1788 - 235ms/epoch - 59ms/step
# Epoch 117/200
# 4/4 - 0s - loss: 0.0329 - root_mean_squared_error: 0.1813 - 236ms/epoch - 59ms/step
# Epoch 118/200
# 4/4 - 0s - loss: 0.0324 - root_mean_squared_error: 0.1799 - 219ms/epoch - 55ms/step
# Epoch 119/200
# 4/4 - 0s - loss: 0.0316 - root_mean_squared_error: 0.1778 - 212ms/epoch - 53ms/step
# Epoch 120/200
# 4/4 - 0s - loss: 0.0323 - root_mean_squared_error: 0.1797 - 208ms/epoch - 52ms/step
# Epoch 121/200
# 4/4 - 0s - loss: 0.0302 - root_mean_squared_error: 0.1736 - 218ms/epoch - 54ms/step
# Epoch 122/200
# 4/4 - 0s - loss: 0.0302 - root_mean_squared_error: 0.1737 - 214ms/epoch - 54ms/step
# Epoch 123/200
# 4/4 - 0s - loss: 0.0319 - root_mean_squared_error: 0.1787 - 228ms/epoch - 57ms/step
# Epoch 124/200
# 4/4 - 0s - loss: 0.0321 - root_mean_squared_error: 0.1792 - 206ms/epoch - 52ms/step
# Epoch 125/200
# 4/4 - 0s - loss: 0.0316 - root_mean_squared_error: 0.1779 - 224ms/epoch - 56ms/step
# Epoch 126/200
# 4/4 - 0s - loss: 0.0317 - root_mean_squared_error: 0.1782 - 203ms/epoch - 51ms/step
# Epoch 127/200
# 4/4 - 0s - loss: 0.0313 - root_mean_squared_error: 0.1769 - 252ms/epoch - 63ms/step
# Epoch 128/200
# 4/4 - 0s - loss: 0.0311 - root_mean_squared_error: 0.1763 - 239ms/epoch - 60ms/step
# Epoch 129/200
# 4/4 - 0s - loss: 0.0318 - root_mean_squared_error: 0.1784 - 223ms/epoch - 56ms/step
# Epoch 130/200
# 4/4 - 0s - loss: 0.0317 - root_mean_squared_error: 0.1779 - 219ms/epoch - 55ms/step
# Epoch 131/200
# 4/4 - 0s - loss: 0.0310 - root_mean_squared_error: 0.1760 - 238ms/epoch - 60ms/step
# Epoch 132/200
# 4/4 - 0s - loss: 0.0319 - root_mean_squared_error: 0.1785 - 215ms/epoch - 54ms/step
# Epoch 133/200
# 4/4 - 0s - loss: 0.0305 - root_mean_squared_error: 0.1745 - 208ms/epoch - 52ms/step
# Epoch 134/200
# 4/4 - 0s - loss: 0.0314 - root_mean_squared_error: 0.1771 - 211ms/epoch - 53ms/step
# Epoch 135/200
# 4/4 - 0s - loss: 0.0328 - root_mean_squared_error: 0.1810 - 213ms/epoch - 53ms/step
# Epoch 136/200
# 4/4 - 0s - loss: 0.0315 - root_mean_squared_error: 0.1774 - 201ms/epoch - 50ms/step
# Epoch 137/200
# 4/4 - 0s - loss: 0.0333 - root_mean_squared_error: 0.1824 - 203ms/epoch - 51ms/step
# Epoch 138/200
# 4/4 - 0s - loss: 0.0317 - root_mean_squared_error: 0.1782 - 198ms/epoch - 50ms/step
# Epoch 139/200
# 4/4 - 0s - loss: 0.0307 - root_mean_squared_error: 0.1751 - 198ms/epoch - 49ms/step
# Epoch 140/200
# 4/4 - 0s - loss: 0.0316 - root_mean_squared_error: 0.1777 - 204ms/epoch - 51ms/step
# Epoch 141/200
# 4/4 - 0s - loss: 0.0313 - root_mean_squared_error: 0.1768 - 212ms/epoch - 53ms/step
# Epoch 142/200
# 4/4 - 0s - loss: 0.0298 - root_mean_squared_error: 0.1725 - 203ms/epoch - 51ms/step
# Epoch 143/200
# 4/4 - 0s - loss: 0.0326 - root_mean_squared_error: 0.1804 - 213ms/epoch - 53ms/step
# Epoch 144/200
# 4/4 - 0s - loss: 0.0315 - root_mean_squared_error: 0.1774 - 205ms/epoch - 51ms/step
# Epoch 145/200
# 4/4 - 0s - loss: 0.0307 - root_mean_squared_error: 0.1752 - 207ms/epoch - 52ms/step
# Epoch 146/200
# 4/4 - 0s - loss: 0.0310 - root_mean_squared_error: 0.1762 - 198ms/epoch - 50ms/step
# Epoch 147/200
# 4/4 - 0s - loss: 0.0310 - root_mean_squared_error: 0.1761 - 211ms/epoch - 53ms/step
# Epoch 148/200
# 4/4 - 0s - loss: 0.0312 - root_mean_squared_error: 0.1766 - 201ms/epoch - 50ms/step
# Epoch 149/200
# 4/4 - 0s - loss: 0.0297 - root_mean_squared_error: 0.1724 - 211ms/epoch - 53ms/step
# Epoch 150/200
# 4/4 - 0s - loss: 0.0302 - root_mean_squared_error: 0.1737 - 207ms/epoch - 52ms/step
# Epoch 151/200
# 4/4 - 0s - loss: 0.0327 - root_mean_squared_error: 0.1809 - 209ms/epoch - 52ms/step
# Epoch 152/200
# 4/4 - 0s - loss: 0.0306 - root_mean_squared_error: 0.1750 - 212ms/epoch - 53ms/step
# Epoch 153/200
# 4/4 - 0s - loss: 0.0317 - root_mean_squared_error: 0.1779 - 204ms/epoch - 51ms/step
# Epoch 154/200
# 4/4 - 0s - loss: 0.0317 - root_mean_squared_error: 0.1781 - 206ms/epoch - 52ms/step
# Epoch 155/200
# 4/4 - 0s - loss: 0.0315 - root_mean_squared_error: 0.1775 - 210ms/epoch - 53ms/step
# Epoch 156/200
# 4/4 - 0s - loss: 0.0318 - root_mean_squared_error: 0.1784 - 206ms/epoch - 51ms/step
# Epoch 157/200
# 4/4 - 0s - loss: 0.0316 - root_mean_squared_error: 0.1777 - 212ms/epoch - 53ms/step
# Epoch 158/200
# 4/4 - 0s - loss: 0.0321 - root_mean_squared_error: 0.1791 - 214ms/epoch - 54ms/step
# Epoch 159/200
# 4/4 - 0s - loss: 0.0319 - root_mean_squared_error: 0.1785 - 227ms/epoch - 57ms/step
# Epoch 160/200
# 4/4 - 0s - loss: 0.0311 - root_mean_squared_error: 0.1763 - 213ms/epoch - 53ms/step
# Epoch 161/200
# 4/4 - 0s - loss: 0.0312 - root_mean_squared_error: 0.1766 - 207ms/epoch - 52ms/step
# Epoch 162/200
# 4/4 - 0s - loss: 0.0314 - root_mean_squared_error: 0.1771 - 229ms/epoch - 57ms/step
# Epoch 163/200
# 4/4 - 0s - loss: 0.0308 - root_mean_squared_error: 0.1755 - 236ms/epoch - 59ms/step
# Epoch 164/200
# 4/4 - 0s - loss: 0.0306 - root_mean_squared_error: 0.1751 - 219ms/epoch - 55ms/step
# Epoch 165/200
# 4/4 - 0s - loss: 0.0309 - root_mean_squared_error: 0.1758 - 208ms/epoch - 52ms/step
# Epoch 166/200
# 4/4 - 0s - loss: 0.0297 - root_mean_squared_error: 0.1723 - 226ms/epoch - 56ms/step
# Epoch 167/200
# 4/4 - 0s - loss: 0.0313 - root_mean_squared_error: 0.1769 - 237ms/epoch - 59ms/step
# Epoch 168/200
# 4/4 - 0s - loss: 0.0311 - root_mean_squared_error: 0.1764 - 225ms/epoch - 56ms/step
# Epoch 169/200
# 4/4 - 0s - loss: 0.0328 - root_mean_squared_error: 0.1810 - 206ms/epoch - 52ms/step
# Epoch 170/200
# 4/4 - 0s - loss: 0.0318 - root_mean_squared_error: 0.1784 - 210ms/epoch - 52ms/step
# Epoch 171/200
# 4/4 - 0s - loss: 0.0302 - root_mean_squared_error: 0.1738 - 209ms/epoch - 52ms/step
# Epoch 172/200
# 4/4 - 0s - loss: 0.0318 - root_mean_squared_error: 0.1782 - 226ms/epoch - 57ms/step
# Epoch 173/200
# 4/4 - 0s - loss: 0.0318 - root_mean_squared_error: 0.1784 - 222ms/epoch - 55ms/step
# Epoch 174/200
# 4/4 - 0s - loss: 0.0315 - root_mean_squared_error: 0.1776 - 237ms/epoch - 59ms/step
# Epoch 175/200
# 4/4 - 0s - loss: 0.0328 - root_mean_squared_error: 0.1811 - 210ms/epoch - 53ms/step
# Epoch 176/200
# 4/4 - 0s - loss: 0.0320 - root_mean_squared_error: 0.1789 - 217ms/epoch - 54ms/step
# Epoch 177/200
# 4/4 - 0s - loss: 0.0309 - root_mean_squared_error: 0.1757 - 208ms/epoch - 52ms/step
# Epoch 178/200
# 4/4 - 0s - loss: 0.0314 - root_mean_squared_error: 0.1771 - 227ms/epoch - 57ms/step
# Epoch 179/200
# 4/4 - 0s - loss: 0.0305 - root_mean_squared_error: 0.1745 - 255ms/epoch - 64ms/step
# Epoch 180/200
# 4/4 - 0s - loss: 0.0320 - root_mean_squared_error: 0.1790 - 210ms/epoch - 53ms/step
# Epoch 181/200
# 4/4 - 0s - loss: 0.0293 - root_mean_squared_error: 0.1712 - 246ms/epoch - 62ms/step
# Epoch 182/200
# 4/4 - 0s - loss: 0.0308 - root_mean_squared_error: 0.1756 - 225ms/epoch - 56ms/step
# Epoch 183/200
# 4/4 - 0s - loss: 0.0317 - root_mean_squared_error: 0.1780 - 238ms/epoch - 59ms/step
# Epoch 184/200
# 4/4 - 0s - loss: 0.0314 - root_mean_squared_error: 0.1771 - 215ms/epoch - 54ms/step
# Epoch 185/200
# 4/4 - 0s - loss: 0.0319 - root_mean_squared_error: 0.1785 - 238ms/epoch - 60ms/step
# Epoch 186/200
# 4/4 - 0s - loss: 0.0314 - root_mean_squared_error: 0.1771 - 203ms/epoch - 51ms/step
# Epoch 187/200
# 4/4 - 0s - loss: 0.0311 - root_mean_squared_error: 0.1765 - 213ms/epoch - 53ms/step
# Epoch 188/200
# 4/4 - 0s - loss: 0.0296 - root_mean_squared_error: 0.1719 - 210ms/epoch - 53ms/step
# Epoch 189/200
# 4/4 - 0s - loss: 0.0313 - root_mean_squared_error: 0.1769 - 212ms/epoch - 53ms/step
# Epoch 190/200
# 4/4 - 0s - loss: 0.0317 - root_mean_squared_error: 0.1781 - 219ms/epoch - 55ms/step
# Epoch 191/200
# 4/4 - 0s - loss: 0.0313 - root_mean_squared_error: 0.1770 - 207ms/epoch - 52ms/step
# Epoch 192/200
# 4/4 - 0s - loss: 0.0305 - root_mean_squared_error: 0.1746 - 211ms/epoch - 53ms/step
# Epoch 193/200
# 4/4 - 0s - loss: 0.0316 - root_mean_squared_error: 0.1778 - 203ms/epoch - 51ms/step
# Epoch 194/200
# 4/4 - 0s - loss: 0.0318 - root_mean_squared_error: 0.1784 - 211ms/epoch - 53ms/step
# Epoch 195/200
# 4/4 - 0s - loss: 0.0309 - root_mean_squared_error: 0.1758 - 205ms/epoch - 51ms/step
# Epoch 196/200
# 4/4 - 0s - loss: 0.0301 - root_mean_squared_error: 0.1734 - 211ms/epoch - 53ms/step
# Epoch 197/200
# 4/4 - 0s - loss: 0.0311 - root_mean_squared_error: 0.1763 - 201ms/epoch - 50ms/step
# Epoch 198/200
# 4/4 - 0s - loss: 0.0319 - root_mean_squared_error: 0.1786 - 207ms/epoch - 52ms/step
# Epoch 199/200
# 4/4 - 0s - loss: 0.0303 - root_mean_squared_error: 0.1740 - 217ms/epoch - 54ms/step
# Epoch 200/200
# 4/4 - 0s - loss: 0.0312 - root_mean_squared_error: 0.1765 - 209ms/epoch - 52ms/step

# %%
print(eas.best_score_, eas.best_params_)
# Out:
# -0.021482365936760336 {'batch_size': 1024, 'epochs': 200, 'optimizer': 'sgd', 'learning_rate': 0.001, 'activation': 'sigmoid', 'dropout': 0.2, 'neurons': 32}

# %%
predictions = eas.predict(test_x)
# Out:
# 1/1 - 0s - 127ms/epoch - 127ms/step
# /home/portes/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/data/ops/structured_function.py:254: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   warnings.warn(

# %%
from sklearn.metrics import mean_squared_error, r2_score

mse = mean_squared_error(test_y, predictions)
r2 = r2_score(test_y, predictions)
mape = np.mean(np.abs((test_y - predictions) / test_y)) * 100
print('MSE: %.3f, R2: %.3f' % (mse, r2))
# Out:
# MSE: 0.022, R2: 0.738

# %%
# Plotar os resultados
pl.figure(figsize=(10, 6))
pl.plot(test_y, label='Valores Reais')
pl.plot(predictions, label='Previsões')
pl.xlabel('Índice')
pl.ylabel('Valor')
pl.title('Comparação entre Valores Reais e Previsões')
pl.legend()
pl.show()
